# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
import numpy as np
import scipy
import sklearn
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.feature_extraction.text import TfidfVectorizer
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from pandas import Series, DataFrame
import nltk

import spacy
import string

from gensim import corpora, models, similarities

import tensorflow as tf
import tensorflow_hub as hub

from gensim.models import Word2Vec
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3516a932-acfc-40bf-bab7-4226093dd15f" name="files[]" multiple disabled />
#      <output id="result-3516a932-acfc-40bf-bab7-4226093dd15f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
df = pd.read_csv('train.csv')
len(df)
# Out:
# 711

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-08cdc9f5-3678-4c99-bbea-99d6b5207ef0" name="files[]" multiple disabled />
#      <output id="result-08cdc9f5-3678-4c99-bbea-99d6b5207ef0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
tdf = pd.read_csv('test.csv')
tdf

# %%
x = df['CONTENT']
y = df['label']
x_test=tdf['CONTENT']
y_test=tdf['label']

# %%
import sklearn.model_selection
from sklearn.model_selection import train_test_split
SEED = 2000
x_train, x_validation, y_train, y_validation = train_test_split(x, y, test_size=.02, random_state=SEED)
print (x_train)

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from time import time

# %%
def accuracy_summary(pipeline, x_train, y_train, x_test, y_test):
    if len(x_test[y_test == 0]) / (len(x_test)*1.) > 0.5:
        null_accuracy = len(x_test[y_test == 0]) / (len(x_test)*1.)
    else:
        null_accuracy = 1. - (len(x_test[y_test == 0]) / (len(x_test)*1.))
    t0 = time()
    sentiment_fit = pipeline.fit(x_train, y_train)
    y_pred = sentiment_fit.predict(x_test)
    train_test_time = time() - t0
    accuracy = accuracy_score(y_test, y_pred)
    print "null accuracy: {0:.2f}%".format(null_accuracy*100)
    print "accuracy score: {0:.2f}%".format(accuracy*100)
    if accuracy > null_accuracy:
        print "model is {0:.2f}% more accurate than null accuracy".format((accuracy-null_accuracy)*100)
    elif accuracy == null_accuracy:
        print "model has the same accuracy with the null accuracy"
    else:
        print "model is {0:.2f}% less accurate than null accuracy".format((null_accuracy-accuracy)*100)
    print "train and test time: {0:.2f}s".format(train_test_time)
    print "-"*80
    return accuracy, train_test_time

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tvec = TfidfVectorizer()
lr = LogisticRegression()
n_features = np.arange(2000,100001,1000)

def nfeature_accuracy_checker(vectorizer=tvec, n_features=n_features, stop_words=None, ngram_range=(1, 1), classifier=lr):
    result = []
    print (classifier)
    print "\n"
    for n in n_features:
        vectorizer.set_params(stop_words=stop_words, max_features=n, ngram_range=ngram_range)
        checker_pipeline = Pipeline([
            ('vectorizer', vectorizer),
            ('classifier', classifier)
        ])
        print "Validation result for {} features".format(n)
        nfeature_accuracy,tt_time = accuracy_summary(checker_pipeline, x_train, y_train, x_validation, y_validation)
        result.append((n,nfeature_accuracy,tt_time))
    return result

# %%
# %%time
print "RESULT FOR UNIGRAM WITH STOP WORDS (Tfidf)\n"
feature_result_ugt = nfeature_accuracy_checker(vectorizer=tvec)
# Out:
# RESULT FOR UNIGRAM WITH STOP WORDS (Tfidf)
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#
#
# Validation result for 2000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.52s
# --------------------------------------------------------------------------------
# Validation result for 3000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.50s
# --------------------------------------------------------------------------------
# Validation result for 4000 features
# null accuracy: 80.00%
# accuracy score: 33.33%
# model is 46.67% less accurate than null accuracy
# train and test time: 0.51s
# --------------------------------------------------------------------------------
# Validation result for 5000 features
# null accuracy: 80.00%
# accuracy score: 33.33%
# model is 46.67% less accurate than null accuracy
# train and test time: 0.51s
# --------------------------------------------------------------------------------
# Validation result for 6000 features
# null accuracy: 80.00%
# accuracy score: 33.33%
# model is 46.67% less accurate than null accuracy
# train and test time: 0.52s
# --------------------------------------------------------------------------------
# Validation result for 7000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.52s
# --------------------------------------------------------------------------------
# Validation result for 8000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.52s
# --------------------------------------------------------------------------------
# Validation result for 9000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 0.53s
# --------------------------------------------------------------------------------
# Validation result for 10000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.53s
# --------------------------------------------------------------------------------
# Validation result for 11000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 0.53s
# --------------------------------------------------------------------------------
# Validation result for 12000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.53s
# --------------------------------------------------------------------------------
# Validation result for 13000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.53s
# --------------------------------------------------------------------------------
# Validation result for 14000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.53s
# --------------------------------------------------------------------------------
# Validation result for 15000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 16000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 17000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.54s
# --------------------------------------------------------------------------------
# Validation result for 18000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 19000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.54s
# --------------------------------------------------------------------------------
# Validation result for 20000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 21000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 22000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 23000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 24000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.58s
# --------------------------------------------------------------------------------
# Validation result for 25000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 26000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.58s
# --------------------------------------------------------------------------------
# Validation result for 27000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 28000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 29000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 30000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 31000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.58s
# --------------------------------------------------------------------------------
# Validation result for 32000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 33000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 34000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 35000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 36000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.58s
# --------------------------------------------------------------------------------
# Validation result for 37000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 38000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.58s
# --------------------------------------------------------------------------------
# Validation result for 39000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 40000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 41000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 42000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.58s
# --------------------------------------------------------------------------------
# Validation result for 43000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.59s
# --------------------------------------------------------------------------------
# Validation result for 44000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 45000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.59s
# --------------------------------------------------------------------------------
# Validation result for 46000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 47000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 48000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 49000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 50000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.58s
# --------------------------------------------------------------------------------
# Validation result for 51000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.59s
# --------------------------------------------------------------------------------
# Validation result for 52000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 53000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 54000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 55000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 56000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 57000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 58000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 59000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 60000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 61000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 62000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 63000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 64000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 65000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 66000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 67000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 68000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 69000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.58s
# --------------------------------------------------------------------------------
# Validation result for 70000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 71000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 72000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 73000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 74000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 75000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 76000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 77000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 78000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 79000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 80000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 81000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 82000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 83000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 84000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 85000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 86000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.54s
# --------------------------------------------------------------------------------
# Validation result for 87000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 88000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 89000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 90000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 91000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 92000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 93000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.55s
# --------------------------------------------------------------------------------
# Validation result for 94000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 95000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 96000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.57s
# --------------------------------------------------------------------------------
# Validation result for 97000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 98000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 99000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# Validation result for 100000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 0.56s
# --------------------------------------------------------------------------------
# CPU times: user 55.5 s, sys: 356 ms, total: 55.8 s
# Wall time: 55.7 s

# %%
# %%time
print "RESULT FOR BIGRAM WITH STOP WORDS (Tfidf)\n"
feature_result_bgt = nfeature_accuracy_checker(vectorizer=tvec,ngram_range=(1, 2))
# Out:
# RESULT FOR BIGRAM WITH STOP WORDS (Tfidf)
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#
#
# Validation result for 2000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 1.91s
# --------------------------------------------------------------------------------
# Validation result for 3000 features
# null accuracy: 80.00%
# accuracy score: 33.33%
# model is 46.67% less accurate than null accuracy
# train and test time: 2.01s
# --------------------------------------------------------------------------------
# Validation result for 4000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.02s
# --------------------------------------------------------------------------------
# Validation result for 5000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 1.92s
# --------------------------------------------------------------------------------
# Validation result for 6000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.02s
# --------------------------------------------------------------------------------
# Validation result for 7000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 1.98s
# --------------------------------------------------------------------------------
# Validation result for 8000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 1.98s
# --------------------------------------------------------------------------------
# Validation result for 9000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.01s
# --------------------------------------------------------------------------------
# Validation result for 10000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 1.98s
# --------------------------------------------------------------------------------
# Validation result for 11000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.03s
# --------------------------------------------------------------------------------
# Validation result for 12000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.09s
# --------------------------------------------------------------------------------
# Validation result for 13000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.00s
# --------------------------------------------------------------------------------
# Validation result for 14000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.06s
# --------------------------------------------------------------------------------
# Validation result for 15000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.08s
# --------------------------------------------------------------------------------
# Validation result for 16000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.03s
# --------------------------------------------------------------------------------
# Validation result for 17000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.03s
# --------------------------------------------------------------------------------
# Validation result for 18000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.05s
# --------------------------------------------------------------------------------
# Validation result for 19000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.08s
# --------------------------------------------------------------------------------
# Validation result for 20000 features
# null accuracy: 80.00%
# accuracy score: 40.00%
# model is 40.00% less accurate than null accuracy
# train and test time: 2.05s
# --------------------------------------------------------------------------------
# Validation result for 21000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.09s
# --------------------------------------------------------------------------------
# Validation result for 22000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.12s
# --------------------------------------------------------------------------------
# Validation result for 23000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.08s
# --------------------------------------------------------------------------------
# Validation result for 24000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.18s
# --------------------------------------------------------------------------------
# Validation result for 25000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.09s
# --------------------------------------------------------------------------------
# Validation result for 26000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.14s
# --------------------------------------------------------------------------------
# Validation result for 27000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.14s
# --------------------------------------------------------------------------------
# Validation result for 28000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.13s
# --------------------------------------------------------------------------------
# Validation result for 29000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.12s
# --------------------------------------------------------------------------------
# Validation result for 30000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.28s
# --------------------------------------------------------------------------------
# Validation result for 31000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.10s
# --------------------------------------------------------------------------------
# Validation result for 32000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.23s
# --------------------------------------------------------------------------------
# Validation result for 33000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.26s
# --------------------------------------------------------------------------------
# Validation result for 34000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.25s
# --------------------------------------------------------------------------------
# Validation result for 35000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.22s
# --------------------------------------------------------------------------------
# Validation result for 36000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.16s
# --------------------------------------------------------------------------------
# Validation result for 37000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.13s
# --------------------------------------------------------------------------------
# Validation result for 38000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.14s
# --------------------------------------------------------------------------------
# Validation result for 39000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.15s
# --------------------------------------------------------------------------------
# Validation result for 40000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.19s
# --------------------------------------------------------------------------------
# Validation result for 41000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.14s
# --------------------------------------------------------------------------------
# Validation result for 42000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.15s
# --------------------------------------------------------------------------------
# Validation result for 43000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.14s
# --------------------------------------------------------------------------------
# Validation result for 44000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.16s
# --------------------------------------------------------------------------------
# Validation result for 45000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.14s
# --------------------------------------------------------------------------------
# Validation result for 46000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.15s
# --------------------------------------------------------------------------------
# Validation result for 47000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.21s
# --------------------------------------------------------------------------------
# Validation result for 48000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.18s
# --------------------------------------------------------------------------------
# Validation result for 49000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.15s
# --------------------------------------------------------------------------------
# Validation result for 50000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.16s
# --------------------------------------------------------------------------------
# Validation result for 51000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.20s
# --------------------------------------------------------------------------------
# Validation result for 52000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.18s
# --------------------------------------------------------------------------------
# Validation result for 53000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 2.18s
# --------------------------------------------------------------------------------
# Validation result for 54000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.15s
# --------------------------------------------------------------------------------
# Validation result for 55000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.20s
# --------------------------------------------------------------------------------
# Validation result for 56000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.21s
# --------------------------------------------------------------------------------
# Validation result for 57000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.23s
# --------------------------------------------------------------------------------
# Validation result for 58000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.36s
# --------------------------------------------------------------------------------
# Validation result for 59000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.23s
# --------------------------------------------------------------------------------
# Validation result for 60000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.23s
# --------------------------------------------------------------------------------
# Validation result for 61000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.32s
# --------------------------------------------------------------------------------
# Validation result for 62000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.33s
# --------------------------------------------------------------------------------
# Validation result for 63000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.24s
# --------------------------------------------------------------------------------
# Validation result for 64000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.22s
# --------------------------------------------------------------------------------
# Validation result for 65000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.24s
# --------------------------------------------------------------------------------
# Validation result for 66000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.22s
# --------------------------------------------------------------------------------
# Validation result for 67000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.28s
# --------------------------------------------------------------------------------
# Validation result for 68000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.21s
# --------------------------------------------------------------------------------
# Validation result for 69000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.23s
# --------------------------------------------------------------------------------
# Validation result for 70000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.28s
# --------------------------------------------------------------------------------
# Validation result for 71000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.25s
# --------------------------------------------------------------------------------
# Validation result for 72000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.26s
# --------------------------------------------------------------------------------
# Validation result for 73000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.23s
# --------------------------------------------------------------------------------
# Validation result for 74000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.23s
# --------------------------------------------------------------------------------
# Validation result for 75000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.26s
# --------------------------------------------------------------------------------
# Validation result for 76000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.25s
# --------------------------------------------------------------------------------
# Validation result for 77000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.27s
# --------------------------------------------------------------------------------
# Validation result for 78000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.26s
# --------------------------------------------------------------------------------
# Validation result for 79000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.30s
# --------------------------------------------------------------------------------
# Validation result for 80000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.41s
# --------------------------------------------------------------------------------
# Validation result for 81000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.41s
# --------------------------------------------------------------------------------
# Validation result for 82000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.38s
# --------------------------------------------------------------------------------
# Validation result for 83000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.25s
# --------------------------------------------------------------------------------
# Validation result for 84000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.26s
# --------------------------------------------------------------------------------
# Validation result for 85000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.27s
# --------------------------------------------------------------------------------
# Validation result for 86000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.28s
# --------------------------------------------------------------------------------
# Validation result for 87000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.26s
# --------------------------------------------------------------------------------
# Validation result for 88000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.30s
# --------------------------------------------------------------------------------
# Validation result for 89000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.24s
# --------------------------------------------------------------------------------
# Validation result for 90000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.30s
# --------------------------------------------------------------------------------
# Validation result for 91000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.26s
# --------------------------------------------------------------------------------
# Validation result for 92000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.29s
# --------------------------------------------------------------------------------
# Validation result for 93000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.28s
# --------------------------------------------------------------------------------
# Validation result for 94000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.31s
# --------------------------------------------------------------------------------
# Validation result for 95000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.31s
# --------------------------------------------------------------------------------
# Validation result for 96000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.32s
# --------------------------------------------------------------------------------
# Validation result for 97000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.30s
# --------------------------------------------------------------------------------
# Validation result for 98000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.31s
# --------------------------------------------------------------------------------
# Validation result for 99000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.32s
# --------------------------------------------------------------------------------
# Validation result for 100000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 2.42s
# --------------------------------------------------------------------------------
# CPU times: user 3min 36s, sys: 701 ms, total: 3min 37s
# Wall time: 3min 37s

# %%
# %%time
print "RESULT FOR TRIGRAM WITH STOP WORDS (Tfidf)\n"
feature_result_tgt = nfeature_accuracy_checker(vectorizer=tvec,ngram_range=(1, 3))
# Out:
# RESULT FOR TRIGRAM WITH STOP WORDS (Tfidf)
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
#
#
# Validation result for 2000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.03s
# --------------------------------------------------------------------------------
# Validation result for 3000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 4.84s
# --------------------------------------------------------------------------------
# Validation result for 4000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.89s
# --------------------------------------------------------------------------------
# Validation result for 5000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.86s
# --------------------------------------------------------------------------------
# Validation result for 6000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.85s
# --------------------------------------------------------------------------------
# Validation result for 7000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.90s
# --------------------------------------------------------------------------------
# Validation result for 8000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.99s
# --------------------------------------------------------------------------------
# Validation result for 9000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.95s
# --------------------------------------------------------------------------------
# Validation result for 10000 features
# null accuracy: 80.00%
# accuracy score: 60.00%
# model is 20.00% less accurate than null accuracy
# train and test time: 4.98s
# --------------------------------------------------------------------------------
# Validation result for 11000 features
# null accuracy: 80.00%
# accuracy score: 60.00%
# model is 20.00% less accurate than null accuracy
# train and test time: 4.89s
# --------------------------------------------------------------------------------
# Validation result for 12000 features
# null accuracy: 80.00%
# accuracy score: 60.00%
# model is 20.00% less accurate than null accuracy
# train and test time: 4.95s
# --------------------------------------------------------------------------------
# Validation result for 13000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.87s
# --------------------------------------------------------------------------------
# Validation result for 14000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.15s
# --------------------------------------------------------------------------------
# Validation result for 15000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.27s
# --------------------------------------------------------------------------------
# Validation result for 16000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.12s
# --------------------------------------------------------------------------------
# Validation result for 17000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.01s
# --------------------------------------------------------------------------------
# Validation result for 18000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 5.08s
# --------------------------------------------------------------------------------
# Validation result for 19000 features
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 5.00s
# --------------------------------------------------------------------------------
# Validation result for 20000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.02s
# --------------------------------------------------------------------------------
# Validation result for 21000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.07s
# --------------------------------------------------------------------------------
# Validation result for 22000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.99s
# --------------------------------------------------------------------------------
# Validation result for 23000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.99s
# --------------------------------------------------------------------------------
# Validation result for 24000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.06s
# --------------------------------------------------------------------------------
# Validation result for 25000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.14s
# --------------------------------------------------------------------------------
# Validation result for 26000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.08s
# --------------------------------------------------------------------------------
# Validation result for 27000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.04s
# --------------------------------------------------------------------------------
# Validation result for 28000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.16s
# --------------------------------------------------------------------------------
# Validation result for 29000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.11s
# --------------------------------------------------------------------------------
# Validation result for 30000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.11s
# --------------------------------------------------------------------------------
# Validation result for 31000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.11s
# --------------------------------------------------------------------------------
# Validation result for 32000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.13s
# --------------------------------------------------------------------------------
# Validation result for 33000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.09s
# --------------------------------------------------------------------------------
# Validation result for 34000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.12s
# --------------------------------------------------------------------------------
# Validation result for 35000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.12s
# --------------------------------------------------------------------------------
# Validation result for 36000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.12s
# --------------------------------------------------------------------------------
# Validation result for 37000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.20s
# --------------------------------------------------------------------------------
# Validation result for 38000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.20s
# --------------------------------------------------------------------------------
# Validation result for 39000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.17s
# --------------------------------------------------------------------------------
# Validation result for 40000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.31s
# --------------------------------------------------------------------------------
# Validation result for 41000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.49s
# --------------------------------------------------------------------------------
# Validation result for 42000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.40s
# --------------------------------------------------------------------------------
# Validation result for 43000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.18s
# --------------------------------------------------------------------------------
# Validation result for 44000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.15s
# --------------------------------------------------------------------------------
# Validation result for 45000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.14s
# --------------------------------------------------------------------------------
# Validation result for 46000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.14s
# --------------------------------------------------------------------------------
# Validation result for 47000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.19s
# --------------------------------------------------------------------------------
# Validation result for 48000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.18s
# --------------------------------------------------------------------------------
# Validation result for 49000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.16s
# --------------------------------------------------------------------------------
# Validation result for 50000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.12s
# --------------------------------------------------------------------------------
# Validation result for 51000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.19s
# --------------------------------------------------------------------------------
# Validation result for 52000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.11s
# --------------------------------------------------------------------------------
# Validation result for 53000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.15s
# --------------------------------------------------------------------------------
# Validation result for 54000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.10s
# --------------------------------------------------------------------------------
# Validation result for 55000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.17s
# --------------------------------------------------------------------------------
# Validation result for 56000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.24s
# --------------------------------------------------------------------------------
# Validation result for 57000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.18s
# --------------------------------------------------------------------------------
# Validation result for 58000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.28s
# --------------------------------------------------------------------------------
# Validation result for 59000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.55s
# --------------------------------------------------------------------------------
# Validation result for 60000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.26s
# --------------------------------------------------------------------------------
# Validation result for 61000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.22s
# --------------------------------------------------------------------------------
# Validation result for 62000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.17s
# --------------------------------------------------------------------------------
# Validation result for 63000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.30s
# --------------------------------------------------------------------------------
# Validation result for 64000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.15s
# --------------------------------------------------------------------------------
# Validation result for 65000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.16s
# --------------------------------------------------------------------------------
# Validation result for 66000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.16s
# --------------------------------------------------------------------------------
# Validation result for 67000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.22s
# --------------------------------------------------------------------------------
# Validation result for 68000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.22s
# --------------------------------------------------------------------------------
# Validation result for 69000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.19s
# --------------------------------------------------------------------------------
# Validation result for 70000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.20s
# --------------------------------------------------------------------------------
# Validation result for 71000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.28s
# --------------------------------------------------------------------------------
# Validation result for 72000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.23s
# --------------------------------------------------------------------------------
# Validation result for 73000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.23s
# --------------------------------------------------------------------------------
# Validation result for 74000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.27s
# --------------------------------------------------------------------------------
# Validation result for 75000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.18s
# --------------------------------------------------------------------------------
# Validation result for 76000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.20s
# --------------------------------------------------------------------------------
# Validation result for 77000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.18s
# --------------------------------------------------------------------------------
# Validation result for 78000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.25s
# --------------------------------------------------------------------------------
# Validation result for 79000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.21s
# --------------------------------------------------------------------------------
# Validation result for 80000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.25s
# --------------------------------------------------------------------------------
# Validation result for 81000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.52s
# --------------------------------------------------------------------------------
# Validation result for 82000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.63s
# --------------------------------------------------------------------------------
# Validation result for 83000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.33s
# --------------------------------------------------------------------------------
# Validation result for 84000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.29s
# --------------------------------------------------------------------------------
# Validation result for 85000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.29s
# --------------------------------------------------------------------------------
# Validation result for 86000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.31s
# --------------------------------------------------------------------------------
# Validation result for 87000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.39s
# --------------------------------------------------------------------------------
# Validation result for 88000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.51s
# --------------------------------------------------------------------------------
# Validation result for 89000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.32s
# --------------------------------------------------------------------------------
# Validation result for 90000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.25s
# --------------------------------------------------------------------------------
# Validation result for 91000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.18s
# --------------------------------------------------------------------------------
# Validation result for 92000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.28s
# --------------------------------------------------------------------------------
# Validation result for 93000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.27s
# --------------------------------------------------------------------------------
# Validation result for 94000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.31s
# --------------------------------------------------------------------------------
# Validation result for 95000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.27s
# --------------------------------------------------------------------------------
# Validation result for 96000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.24s
# --------------------------------------------------------------------------------
# Validation result for 97000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.61s
# --------------------------------------------------------------------------------
# Validation result for 98000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.58s
# --------------------------------------------------------------------------------
# Validation result for 99000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.26s
# --------------------------------------------------------------------------------
# Validation result for 100000 features
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.29s
# --------------------------------------------------------------------------------
# CPU times: user 8min 30s, sys: 2.17 s, total: 8min 33s
# Wall time: 8min 33s

# %%
nfeatures_plot_tgt = pd.DataFrame(feature_result_tgt,columns=['nfeatures','validation_accuracy','train_test_time'])
nfeatures_plot_bgt = pd.DataFrame(feature_result_bgt,columns=['nfeatures','validation_accuracy','train_test_time'])
nfeatures_plot_ugt = pd.DataFrame(feature_result_ugt,columns=['nfeatures','validation_accuracy','train_test_time'])

plt.figure(figsize=(8,6))
plt.plot(nfeatures_plot_tgt.nfeatures, nfeatures_plot_tgt.validation_accuracy,label='trigram tfidf vectorizer',color='royalblue')
#plt.plot(nfeatures_plot_tgt.nfeatures, nfeatures_plot_tgt.validation_accuracy,label='trigram count vectorizer',linestyle=':', color='royalblue')
plt.plot(nfeatures_plot_bgt.nfeatures, nfeatures_plot_bgt.validation_accuracy,label='bigram tfidf vectorizer',color='orangered')
#plt.plot(nfeatures_plot_bgt.nfeatures, nfeatures_plot_bgt.validation_accuracy,label='bigram count vectorizer',linestyle=':',color='orangered')
plt.plot(nfeatures_plot_ugt.nfeatures, nfeatures_plot_ugt.validation_accuracy, label='unigram tfidf vectorizer',color='gold')
#plt.plot(nfeatures_plot_ugt.nfeatures, nfeatures_plot_ugt.validation_accuracy, label='unigram count vectorizer',linestyle=':',color='gold')
plt.title("N-gram(1~3) test result : Accuracy")
plt.xlabel("Number of features")
plt.ylabel("Validation set accuracy")
plt.legend()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import Perceptron
from sklearn.neighbors import NearestCentroid
from sklearn.feature_selection import SelectFromModel

names = ["Logistic Regression", "Linear SVC", "LinearSVC with L1-based feature selection","Multinomial NB", 
         "Bernoulli NB", "Ridge Classifier", "AdaBoost", "Perceptron","Passive-Aggresive", "Nearest Centroid"]
classifiers = [
    LogisticRegression(),
    LinearSVC(),
    Pipeline([
  ('feature_selection', SelectFromModel(LinearSVC(penalty="l1", dual=False))),
  ('classification', LinearSVC(penalty="l2"))]),
    MultinomialNB(),
    BernoulliNB(),
    RidgeClassifier(),
    AdaBoostClassifier(),
    Perceptron(),
    PassiveAggressiveClassifier(),
    NearestCentroid()
    ]
zipped_clf = zip(names,classifiers)

# %%
tvec = TfidfVectorizer()
def classifier_comparator(vectorizer=tvec, n_features=10000, stop_words=None, ngram_range=(1, 1), classifier=zipped_clf):
    result = []
    vectorizer.set_params(stop_words=stop_words, max_features=n_features, ngram_range=ngram_range)
    for n,c in classifier:
        checker_pipeline = Pipeline([
            ('vectorizer', vectorizer),
            ('classifier', c)
        ])
        print "Validation result for {}".format(n)
        print c
        clf_accuracy,tt_time = accuracy_summary(checker_pipeline, x_train, y_train, x_validation, y_validation)
        result.append((n,clf_accuracy,tt_time))
    return result

# %%
# %%time
trigram_result = classifier_comparator(n_features=10000,ngram_range=(1,3))
# Out:
# Validation result for Logistic Regression
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# null accuracy: 80.00%
# accuracy score: 60.00%
# model is 20.00% less accurate than null accuracy
# train and test time: 4.85s
# --------------------------------------------------------------------------------
# Validation result for Linear SVC
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.85s
# --------------------------------------------------------------------------------
# Validation result for LinearSVC with L1-based feature selection
# Pipeline(memory=None,
#      steps=[('feature_selection', SelectFromModel(estimator=LinearSVC(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=None, tol=0.0001,
#      verbose=0),
#         max_features=None, n...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 5.06s
# --------------------------------------------------------------------------------
# Validation result for Multinomial NB
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.72s
# --------------------------------------------------------------------------------
# Validation result for Bernoulli NB
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)
# null accuracy: 80.00%
# accuracy score: 60.00%
# model is 20.00% less accurate than null accuracy
# train and test time: 4.96s
# --------------------------------------------------------------------------------
# Validation result for Ridge Classifier
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=None, solver='auto',
#         tol=0.001)
# null accuracy: 80.00%
# accuracy score: 46.67%
# model is 33.33% less accurate than null accuracy
# train and test time: 5.04s
# --------------------------------------------------------------------------------
# Validation result for AdaBoost
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)
# null accuracy: 80.00%
# accuracy score: 33.33%
# model is 46.67% less accurate than null accuracy
# train and test time: 6.78s
# --------------------------------------------------------------------------------
# Validation result for Perceptron
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#       fit_intercept=True, max_iter=None, n_iter=None, n_iter_no_change=5,
#       n_jobs=None, penalty=None, random_state=0, shuffle=True, tol=None,
#       validation_fraction=0.1, verbose=0, warm_start=False)
# /usr/local/lib/python2.7/dist-packages/sklearn/linear_model/stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in Perceptron in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# null accuracy: 80.00%
# accuracy score: 60.00%
# model is 20.00% less accurate than null accuracy
# train and test time: 4.79s
# --------------------------------------------------------------------------------
# Validation result for Passive-Aggresive
# PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#               early_stopping=False, fit_intercept=True, loss='hinge',
#               max_iter=None, n_iter=None, n_iter_no_change=5, n_jobs=None,
#               random_state=None, shuffle=True, tol=None,
#               validation_fraction=0.1, verbose=0, warm_start=False)
# /usr/local/lib/python2.7/dist-packages/sklearn/linear_model/stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in PassiveAggressiveClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# null accuracy: 80.00%
# accuracy score: 66.67%
# model is 13.33% less accurate than null accuracy
# train and test time: 5.38s
# --------------------------------------------------------------------------------
# Validation result for Nearest Centroid
# NearestCentroid(metric='euclidean', shrink_threshold=None)
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.00s
# --------------------------------------------------------------------------------
# CPU times: user 51.1 s, sys: 308 ms, total: 51.4 s
# Wall time: 51.5 s

# %%
from sklearn.ensemble import VotingClassifier

clf1 = PassiveAggressiveClassifier()
clf2 = Perceptron()
clf3 = MultinomialNB()
clf4 = LogisticRegression()
clf5 = LinearSVC()

eclf = VotingClassifier(estimators=[('pa', clf1), ('pc', clf2), ('mnb', clf3), ('lr', clf4), ('lsvc', clf5)], voting='hard')

for clf, label in zip([clf1, clf2, clf3, clf4, clf5, eclf], ['PassiveAggressiveClassifier', 'Perceptron', 'Multinomial NB', 'LogisticRegression', 'LinearSVC', 'Ensemble']):
    checker_pipeline = Pipeline([
            ('vectorizer', TfidfVectorizer(max_features=10000,ngram_range=(1, 3))),
            ('classifier', clf)
        ])
    print "Validation result for {}".format(label)
    print clf
    clf_accuracy,tt_time = accuracy_summary(checker_pipeline, x_train, y_train, x_validation, y_validation)
# Out:
# Validation result for PassiveAggressiveClassifier
# PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#               early_stopping=False, fit_intercept=True, loss='hinge',
#               max_iter=None, n_iter=None, n_iter_no_change=5, n_jobs=None,
#               random_state=None, shuffle=True, tol=None,
#               validation_fraction=0.1, verbose=0, warm_start=False)
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.93s
# --------------------------------------------------------------------------------
# Validation result for Perceptron
# Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#       fit_intercept=True, max_iter=None, n_iter=None, n_iter_no_change=5,
#       n_jobs=None, penalty=None, random_state=0, shuffle=True, tol=None,
#       validation_fraction=0.1, verbose=0, warm_start=False)
# null accuracy: 80.00%
# accuracy score: 60.00%
# model is 20.00% less accurate than null accuracy
# train and test time: 4.89s
# --------------------------------------------------------------------------------
# Validation result for Multinomial NB
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.82s
# --------------------------------------------------------------------------------
# Validation result for LogisticRegression
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)
# null accuracy: 80.00%
# accuracy score: 60.00%
# model is 20.00% less accurate than null accuracy
# train and test time: 4.90s
# --------------------------------------------------------------------------------
# Validation result for LinearSVC
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 4.92s
# --------------------------------------------------------------------------------
# Validation result for Ensemble
# VotingClassifier(estimators=[('pa', PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#               early_stopping=False, fit_intercept=True, loss='hinge',
#               max_iter=None, n_iter=None, n_iter_no_change=5, n_jobs=None,
#               random_state=None, shuffle=True, tol=None,
#           ...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))],
#          flatten_transform=None, n_jobs=None, voting='hard', weights=None)
# null accuracy: 80.00%
# accuracy score: 53.33%
# model is 26.67% less accurate than null accuracy
# train and test time: 5.14s
# --------------------------------------------------------------------------------
