# %% [markdown]
# # Web Scraping: The CNBC

# %%
from datetime import datetime
import numpy as np
import pandas as pd


from bs4 import BeautifulSoup
from selenium import webdriver
import time

import requests
import re

# %% [markdown]
# ### Obtain list of news from the coverpage

# %% [markdown]
# URL definition:

# %%
# url definition
url = "https://www.cnbc.com"

# %% [markdown]
# List of news:

# %%
# Request
r1 = requests.get(url)
print(r1.status_code)

# We'll save in coverpage the cover page content
coverpage = r1.content

# Soup creation
soup1 = BeautifulSoup(coverpage, 'html5lib')

# News identification
coverpage_news = soup1.find_all('a', class_='LazyLoaderPlaceholder-headline')
len(coverpage_news)
# Out:
# 200
# 67

# %% [markdown]
# Now we have a list in which every element is a news article:

# %%
coverpage_news[0]
# Out:
# <a class="LazyLoaderPlaceholder-headline" href="https://www.cnbc.com/2019/10/02/chinas-fake-meat-trend-is-on-the-rise-researchers-say.html">China's fake meat trend is on the rise, researchers say</a>

# %%
n=0
link = coverpage_news[n]['href']
title = coverpage_news[n].get_text()
article = requests.get(link)
article_content = article.content
soup_article = BeautifulSoup(article_content, 'html5lib')

# %%
title
# Out:
# "China's fake meat trend is on the rise, researchers say"

# %%
body = soup_article.find_all('p')

# %%
body
# Out:
# [<p><input type="checkbox"/>Keep Me Logged In</p>,
#  <p class="TickerStory-storyDescription">Wednesday's report of ADP private payrolls could give clues on the labor market, the next part of the economy to be scrutinized.</p>,
#  <p class="TickerStory-storyDescription">Sen. Elizabeth Warren could see a major boost from donors in Silicon Valley who are drawn to her Big Tech proposals.</p>,
#  <p class="TickerStory-storyDescription">Forever 21 on Tuesday released a list of the nearly 180 locations it expects to close as part of its bankruptcy proceedings, including those stores' owners. When the apparel...</p>,
#  <p class="TickerStory-storyDescription">The pro-Trump groups, which also include his joint fundraising entities, have raised more than $308 million in total in 2019, and boast more than $156 million cash on hand.</p>,
#  <p class="TickerStory-storyDescription">If current employees are going into the all-hands meetings and recording audio of their CEO, that is a sign that employee morale is in the dumps, multiple former Facebook...</p>,
#  <p class="TickerStory-storyDescription">"This is purely about protecting investors from garbage merchandise," the "Mad Money" host says.</p>,
#  <p class="TickerStory-storyDescription">Shares of Uber and Lyft fell to fresh lows on Tuesday, posting their lowest close ever, as the ride-hailing firms join a string of recently public companies facing fresh...</p>,
#  <p class="TickerStory-storyDescription">The CEO of enterprise software company Outreach told CNBC that he learned direct listings can be beneficial even for businesses that aren't widely known.</p>,
#  <p class="TickerStory-storyDescription">Harris' $11.6 million third-quarter haul trails the amount raised by Sen. Bernie Sanders and South Bend, Indiana, Mayor Pete Buttigieg.</p>,
#  <p class="TickerStory-storyDescription">Recession red signals are weighing on stocks, and the fourth-quarter 2018 was a disaster, but over the past decade the final quarter of trading has been the best for the S&amp;P...</p>,
#  <p class="TickerStory-storyDescription">Banned running coach Alberto Salazar briefed Nike CEO Mark Parker on doping violations on multiple occasions, according to materials released Monday by the U.S. Anti-Doping...</p>,
#  <p class="TickerStory-storyDescription">Stitch Fix's active client base grew 18% year over year, reaching 3.2 million people, the company said when it reported earnings after the bell on Tuesday.</p>,
#  <p><a alt="" aria-label="" class="" data-type="" href="https://www.cnbc.com/china/" rel="" role="" tabindex="" target="" title="">Chinese</a> demand for "mock meat" is going up amid concerns that the domestic supply won't be enough to meet demand, according to research house Fitch Solutions.</p>,
#  <p>In a country where pork is a staple, the <a alt="" aria-label="" class="" data-type="" href="https://www.cnbc.com/2019/07/30/chinas-pig-herd-predicted-to-shrink-due-to-african-swine-fever.html" rel="" role="" tabindex="" target="" title="">African swine fever outbreak</a> is one factor that has pushed down supplies of the meat, Fitch noted <a alt="" aria-label="" class="" data-type="" href="https://www.fitchsolutions.com/retail-consumer/china-ready-fake-meat-18-09-2019" rel="" role="" tabindex="" target="" title="">in a report released September</a>.</p>,
#  <p>African swine fever is a highly contagious and fatal viral infection that has led to the culling of some 1.17 million hogs in China, <a alt="" aria-label="" class="" data-type="" href="http://www.fao.org/ag/againfo/programmes/en/empres/ASF/situation_update.html" rel="" role="" tabindex="" target="" title="">according to the UN's Food and Agriculture Organization</a>. </p>,
#  <p>China is <a alt="" aria-label="" class="" data-type="" href="https://apps.fas.usda.gov/newgainapi/api/report/downloadreportbyfilename?filename=Livestock%20and%20Products%20Annual_Beijing_China%20-%20Peoples%20Republic%20of_7-22-2019.pdf" rel="" role="" tabindex="" target="" title="">one of the highest consumers of pork</a> in the world. It was also the <a alt="" aria-label="" class="" data-type="" href="https://www.statista.com/statistics/263964/number-of-pigs-in-selected-countries/" rel="" role="" tabindex="" target="" title="">largest producer of pork</a> in the world in 2018, according to data firm Statista.</p>,
#  <p>As supplies dwindle, more meat imports may be needed to meet consumer demand, the Fitch report stated. Alternatively, "new options would need to be investigated and encouraged" in order to increase the supply of meat, the report said.</p>,
#  <p>Mock meat is one option.</p>,
#  <p>In 2018, China's plant-based meat industry was worth $910 million — up 14.2% from a year earlier, according to a report by <a alt="" aria-label="" class="" data-type="" href="https://www.gfi.org/new-gfi-report-illustrates-the-state-of-chinas" rel="" role="" tabindex="" target="" title="">U.S.-based Good Food Institute</a>. In comparison, the U.S. market stood at $684 million that year — increasing by 23% year-on-year, the non-profit organization said.</p>,
#  <p>African swine fever, in particular, will be "positive" for the Chinese alternative meat industry, said Simon Powell, a researcher at U.S. investment bank Jefferies.</p>,
#  <p>The deadly disease might have led to a 20 million ton drop in China's pork market, according to Powell. On this decrease, consumers could turn to mock meat as an alternative.</p>,
#  <p>"I think there could be tremendous pull through for alternative protein, alternative meat here," he told CNBC last Wednesday.</p>,
#  <p>Another factor behind the mock meat trend is Chinese cuisine, Fitch Solutions said in their report. That's because plant-based mock meats, made of tofu or wheat-based seitan, are already<strong> </strong>traditionally used in Chinese dishes.</p>,
#  <p>In fact, some say that the Chinese began eating alternative meat as early as the Tang Dynasty, more than a thousand years ago.</p>,
#  <p>"The fake meat trend can be viewed as the next step in this tradition as opposed to a completely new development," the report said.</p>,
#  <p>Environmental, ethical, and health concerns may also be behind the growing demand for fake meat in China, the Fitch report noted. </p>,
#  <p>Chinese millennials and flexitarians — or people who reduce their meat intake for health or environmental reasons — could lead the way for alternative meat, Powell told CNBC.</p>,
#  <p>Despite this trend, it could be a while before mock meat consumption in China becomes widespread.</p>,
#  <p>"One would never assume that it would be on a mass scale," Powell said, adding that pork, in particular, is important to the Chinese everyday diet and national psyche.</p>,
#  <p>Chinese demand for meat has historically been high. In 2018, the country accounted for approximately 46% of the total world's pork consumption, <a alt="" aria-label="" class="" data-type="" href="https://data.oecd.org/agroutput/meat-consumption.htm" rel="" role="" tabindex="" target="" title="">according to OECD data</a>.</p>,
#  <p class="Footer-sectionInfo">Got a confidential news tip? We want to hear from you.</p>,
#  <p class="Footer-sectionInfo">Sign up for free newsletters and get more CNBC delivered to your inbox</p>,
#  <p class="Footer-copyright">Get this delivered to your inbox, and more info about our products and services. <a href="https://www.nbcuniversal.com/privacy/">Privacy Policy.</a></p>,
#  <p class="Footer-copyright">© <!-- -->2019<!-- --> CNBC LLC. All Rights Reserved.<!-- --> <a href="http://www.nbcuni.com/">A Division of NBCUniversal</a></p>,
#  <p class="Footer-copyright">Data is a real-time snapshot *Data is delayed at least 15 minutes. Global Business and Financial News, Stock Quotes, and Market Data and Analysis.</p>,
#  <p class="Footer-copyright">Data also provided by<!-- --> <a href="//www.cnbc.com/market-data-terms-of-service/"><img alt="Reuters" class="Footer-reutersLogo" src="data:image/svg+xml;base64,..."/></a></p>]

# %%
len(body)
# Out:
# 37

# %%
x = soup_article.find_all('p')

# %%
len(x)
# Out:
# 37

# %%
x[0].get_text()
# Out:
# 'Keep Me Logged In'

# %%
# options = webdriver.ChromeOptions() 
# options.add_experimental_option("excludeSwitches", ['enable-automation'])
# def Article(url):
#     browser = webdriver.Chrome(chrome_options=options, executable_path=r"/usr/bin/chromedriver")
#     browser.get(url)
#     time.sleep(5) # wait for the page to load javascript
#     pageSource = browser.page_source
#     browser.quit()
#     return pageSource

# %% [markdown]
# ### Let's extract the text from the articles:

# %% [markdown]
# First, we'll define the number of articles we want:

# %%
number_of_articles = len(coverpage_news)-1
now = datetime.now()

# %%
# Empty lists for content, links and titles
news_contents = []
list_links = []
list_titles = []
scrapedTime=[]
postedDate=[]
for n in np.arange(0, number_of_articles):
        
    # Getting the link of the article
    link = coverpage_news[n]['href']
    print (link)
    list_links.append(link)
    posteddate=re.findall(r'/(\d{4})/(\d{1,2})/(\d{1,2})/', link)
    #posteddate=str(posteddate)
    if posteddate:
        posteddate=','.join(posteddate[0]) 
        posteddate=posteddate.replace(',','/')
    print (posteddate)
    postedDate.append(posteddate)
    
    # Getting the title
    title = coverpage_news[n].get_text()
    list_titles.append(title)
    
    
    # Reading the content (it is divided in paragraphs)
    article = requests.get(link)
    article_content = article.content
    soup_article = BeautifulSoup(article_content, 'html5lib')
    x = soup_article.find_all('p')
    scraped = now.strftime("%d/%m/%Y %H:%M:%S")
    scrapedTime.append(scraped)
    # Unifying the paragraphs
    list_paragraphs = []
    for p in np.arange(0, len(x)):
        paragraph = x[p].get_text()
        list_paragraphs.append(paragraph)
        final_article = " ".join(list_paragraphs)
        
        news_contents.append(final_article)
# Out:
# https://www.cnbc.com/2019/10/02/chinas-fake-meat-trend-is-on-the-rise-researchers-say.html
# 2019/10/02
# https://www.cnbc.com/2019/10/01/bill-gurley-direct-listing-event-convinced-outreach-ceo-to-consider-it.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01
html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/papa-johns-ceo-says-unlike-dominos-they-are-embracing-doordash.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/charles-schwab-is-eliminating-online-commissions-for-trading-in-us-stocks-and-etfs.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/former-gop-rep-chris-collins-pleads-guilty-in-insider-trading-case.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/silicon-valley-ready-to-back-elizabeth-warren-despite-tech-break-up-plan.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/white-house-floated-memo-to-study-china-investment-limits-amid-trade-war.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/us-court-says-fcc-cannot-bar-states-from-setting-net-neutrality-rules.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/cory-booker-raises-over-6-million-in-the-third-quarter.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/pompeo-rips-dem-attempts-to-bully-state-officials-over-depositions.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/trump-targets-pathetic-fed-after-worst-manufacturing-reading-in-a-decade.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/2020-democratic-primary-bernie-sanders-campaign-raises-25-million.html
# 2019/10/01
# https://www.cnbc.com/2019/09/30/why-this-founder-turned-down-300000-from-mark-cuban-on-shark-tank.html
# 2019/09/30
# https://www.cnbc.com/2019/10/01/eating-less-red-meat-does-not-improve-according-to-controversial-new-health-study.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/how-to-get-hired-at-ritual-according-to-founder-katerina-schneider.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/us-news-world-report-10-highest-paying-lowest-stress-jobs.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/photos-final-home-designed-by-frank-lloyd-wright-to-go-up-for-auction.html
# 2019/10/01
# https://www.cnbc.com/video/2019/10/01/take-a-look-inside-frank-lloyd-wrights-last-home-thats-up-for-auction.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/lawmakers-want-to-give-students-with-drug-convictions-access-to-financial-aid.html
# 2019/10/01
# https://www.cnbc.com/2019/10/01/umb-bank-and-dc-partnered-to-offer-the-dc-power-rewards-visa-card.html
# 2019/10/01
# https://grow.acorns.com/average-401k-balances-by-age/
# []
# https://grow.acorns.com/debt-free-strategies/
# []
# https://grow.acorns.com/credit-card-debt-personal-loan/
# []
# https://grow.acorns.com/how-much-you-can-earn-in-one-of-the-fastest-growing-jobs/
# []
# https://grow.acorns.com/how-to-decode-expiration-dates-and-make-your-food-last-longer/
# []
# https://grow.acorns.com/stock-market-outlook-for-october/
# []
# https://grow.acorns.com/file-the-fafsa-in-october-to-maximize-college-aid/
# []

# %%
len(postedDate)
# Out:
# 66

# %% [markdown]
# Let's put them into:
# * a dataset which will the input of the models (`df_features`)
# * a dataset with the title and the link (`df_show_info`)

# %%
# df_features
df_features = pd.DataFrame(
     {'Article Content': news_contents 
    })

# df_show_info
df_show_info = pd.DataFrame(
    {'Article Title': list_titles,
     'Article Link': list_links})

# %%
df=pd.DataFrame(columns= ["STOCK ID", "URL", "PUBLISH TIME", "EDITED TIME", "SCRAPED TIME", "TITLE", "CONTENT" ])
df['URL']=list_links
df['PUBLISH TIME']=postedDate
df['SCRAPED TIME']=scrapedTime
df['TITLE']=list_titles
df['CONTENT']=news_contents
df
# Out:
#    STOCK ID                                                URL PUBLISH TIME  \
# 0       NaN  https://www.cnbc.com/2019/10/02/chinas-fake-me...   2019/10/02
# 1       NaN  https://www.cnbc.com/2019/10/01/bill-gurley-di...   2019/10/01
# 2       NaN  https://www.cnbc.com/2019/10/01/tesla-acquirin...   2019/10/01
# 3       NaN  https://www.cnbc.com/2019/10/01/banned-coach-a...   2019/10/01
# 4       NaN  https://www.cnbc.com/2019/10/01/visa-mastercar...   2019/10/01
# 42         NaN  02/10/2019 17:24:34
# 43         NaN  02/10/2019 17:24:34
# 44         NaN  02/10/2019 17:24:34
# 45         NaN  02/10/2019 17:24:34
# 46         NaN  02/10/2019 17:24:34
# 47         NaN  02/10/2019 17:24:34
# 48         NaN  02/10/2019 17:24:34
# 49         NaN  02/10/2019 17:24:34
# 50         NaN  02/10/2019 17:24:34
# 51         NaN  02/10/2019 17:24:34
# 52         NaN  02/10/2019 17:24:34
# 53         NaN  02/10/2019 17:24:34
# 54         NaN  02/10/2019 17:24:34
# 55         NaN  02/10/2019 17:24:34
# 56         NaN  02/10/2019 17:24:34
# 57         NaN  02/10/2019 17:24:34
# 58         NaN  02/10/2019 17:24:34
# 59         NaN  02/10/2019 17:24:34
# 60         NaN  02/10/2019 17:24:34
# 61         NaN  02/10/2019 17:24:34
# 62         NaN  02/10/2019 17:24:34
# 63         NaN  02/10/2019 17:24:34
# 64         NaN  02/10/2019 17:24:34
# 65         NaN  02/10/2019 17:24:34
#
#                                                 TITLE  \
# 0   China's fake meat trend is on the rise, resear...
# 1   You don't have to be a big brand name to do a ...
# 2   Tesla is buying computer vision start-up DeepS...
# 3   Banned coach Alberto Salazar briefed Nike CEO ...
# 4   Visa, Mastercard reconsider backing Facebook's...
# 5   Meet Triple Five Group: The developers behind ...
# 6   Those weekly splurges cost $7,400 extra annual...
# 7   The final home designed by Frank Lloyd Wright ...
# 8   Johnson & Johnson settles with Ohio counties a...
# 9   Health-care stocks are in their longest losing...
# 10  How to save $1 million on a $100,000 salary, b...
# 11  Tesla is buying computer vision start-up DeepS...
# 12  Three new Microsoft Surface computers leak ahe...
# 13  You don't have to be a big brand name to do a ...
# 14  Leaked Facebook audio is a sign of decreased m...
# 15  Uber and Lyft close at record lows as investor...
# 16  WeWork property defaults may be next after fai...
# 17  Silicon Valley donors starting to back Elizabe...
# 18  Despite recession talk, CMOs are optimistic ab...
# 19  Stitch Fix shares fall despite earnings beat, ...
# 20  UAW submits counteroffer to 'comprehensive,' y...
# 21  Here's a map of the Forever 21 stores that cou...
# 22  FDA issues warning on medical devices that are...
# 23  Meet Triple Five Group: The developers behind ...
# 24  GM lays off 6,000 additional workers in Mexico...
# 25  Banned coach Alberto Salazar briefed Nike CEO ...
# 26  Coca-Cola to launch Coke-branded energy drink ...
# 27  Those weekly splurges cost $7,400 extra annual...
# 28  More than 25% of millennials are keeping a fin...
# 29  What you don't know about managing money can c...
# ..                                                ...
# 36  Atlanta Fed's GDP tracker points to less than ...
# 37  Wall Street starting to think Warren may win n...
# 38  McDonald's slides after JP Morgan analyst says...
# 39  Disney and these two other stocks are Bank of ...
# 40  Cramer to Wall Street: 'I want to stop the fea...
# 41  Papa John's CEO says, unlike Domino's, they're...
# 42  Charles Schwab is ending commissions on stock ...
# 43  Former GOP Rep. Chris Collins pleads guilty in...
# 44  Silicon Valley donors starting to back Elizabe...
# 45  White House floated memo to study Chinese inve...
# 46  US court says FCC cannot bar states from setti...
# 47  Cory Booker raises over $6 million in the thir...
# 48  Pompeo rips Dem attempts to 'bully' State Dept...
# 49  Trump targets 'pathetic' Federal Reserve after...
# 50  Bernie Sanders campaign says it raised a massi...
# 51  Why this falafel business founder turned down ...
# 52  Study suggests eating less red and processed m...
# 53  Ritual founder Katerina Schneider isn't intere...
# 54  The highest-paying low-stress job in the US pa...
# 55  The final home designed by Frank Lloyd Wright ...
# 56  Take a look inside Frank Lloyd Wright's last h...
# 57  Lawmakers want to give students with drug conv...
# 58  UMB Bank and DC are offering a new rewards cre...
# 59  Average 401(k) balances by age: See how your r...
# 60  6 strategies that helped these people pay off ...
# 61  One easy move that can help you dig out of cre...
# 62  5 of the fastest-growing jobs in America and h...
# 63  How to decode expiration dates — and make your...
# 64  Next round of US-China trade talks and start o...
# 65  Filing this key form in October can double the...
#
#                                               CONTENT
# 0   Keep Me Logged In U.S. markets fell broadly fo...
# 1   Keep Me Logged In U.S. markets fell broadly fo...
# 2   Keep Me Logged In U.S. markets fell broadly fo...
# 3   Keep Me Logged In U.S. markets fell broadly fo...
# 4   Keep Me Logged In U.S. markets fell broadly fo...
# 5   Keep Me Logged In U.S. markets fell broadly fo...
# 6   Keep Me Logged In Sticking to a household budg...
# 7   The legendary Norman Lykes house, designed by ...
# 8   Keep Me Logged In U.S. markets fell broadly fo...
# 9   Keep Me Logged In The health-care sector just ...
# 10  Keep Me Logged In Even if you are making $100,...
# 11  Keep Me Logged In U.S. markets fell broadly fo...
# 12  Keep Me Logged In U.S. markets fell broadly fo...
# 13  Keep Me Logged In U.S. markets fell broadly fo...
# 14  Keep Me Logged In U.S. markets fell broadly fo...
# 15  Keep Me Logged In U.S. markets fell broadly fo...
# 16  Keep Me Logged In U.S. markets fell broadly fo...
# 17  Keep Me Logged In Sen. Elizabeth Warren has vo...
# 18  Keep Me Logged In U.S. markets fell broadly fo...
# 19  Keep Me Logged In U.S. markets fell broadly fo...
# 20  Keep Me Logged In U.S. markets fell broadly fo...
# 21  Keep Me Logged In U.S. markets fell broadly fo...
# 22  Keep Me Logged In U.S. markets fell broadly fo...
# 23  Keep Me Logged In U.S. markets fell broadly fo...
# 24  Keep Me Logged In U.S. markets fell broadly fo...
# 25  Keep Me Logged In U.S. markets fell broadly fo...
# 26  Keep Me Logged In U.S. markets fell broadly fo...
# 27  Keep Me Logged In Sticking to a household budg...
# 28  Keep Me Logged In U.S. markets fell broadly fo...
# 29  Keep Me Logged In It's possible to be a succes...
# ..                                                ...
# 36  Keep Me Logged In U.S. markets fell broadly fo...
# 37  Keep Me Logged In U.S. markets fell broadly fo...
# 38  Keep Me Logged In U.S. markets fell broadly fo...
# 39  Keep Me Logged In U.S. markets fell broadly fo...
# 40  Keep Me Logged In U.S. markets fell broadly fo...
# 41  Keep Me Logged In U.S. markets fell broadly fo...
# 42  Keep Me Logged In U.S. markets fell broadly fo...
# 43  Keep Me Logged In U.S. markets fell broadly fo...
# 44  Keep Me Logged In Sen. Elizabeth Warren has vo...
# 45  Keep Me Logged In U.S. markets fell broadly fo...
# 46  Keep Me Logged In U.S. markets fell broadly fo...
# 47  Keep Me Logged In Sen. Cory Booker is breathin...
# 48  Keep Me Logged In U.S. markets fell broadly fo...
# 49  Keep Me Logged In U.S. markets fell broadly fo...
# 50  Keep Me Logged In Sen. Bernie Sanders' campaig...
# 51  To be a startup founder in a make-or-break mom...
# 52  Most of us have heard that red meat and proces...
# 53  Katerina Schneider's resume is impressive. She...
# 54  If you want a job with healthy work-life balan...
# 55  The legendary Norman Lykes house, designed by ...
# 56  Data is a real-time snapshot *Data is delayed ...
# 57  If you're convicted of burglary, you can still...
# 58  Thousands of fans are getting ready to convene...
# 59  A record number of Americans are "401(k) milli...
# 60  Getting out of debt isn't easy. It usually req...
# 61  Collectively, U.S. consumers have a massive $8...
# 62  We're in what experts have described as the "g...
# 63  Americans toss out almost a pound of food per ...
# 64  Welcome to our monthly stock market outlook, w...
# 65  Starting October 1, families can file the Free...
#
# [66 rows x 7 columns]

# %%
st=pd.DataFrame(pd.read_csv('c:/data/CS/tickers_list.csv'))
st['Issuer Name'][0].split(',')
issuerName=[]
stockabbre=[]
for i in range(len(st['Issuer Name'])):
    issuername=st['Issuer Name'][i].split(',')
    issuerName.append(issuername[0])
print (issuerName)
stockabbre=st["Symbol"]
stockabbre=list(stockabbre)
stockabbre.append('APPL')
print (stockabbre)
# Out:
# ['ADOMANI', 'AdvisorShares Trust', 'Allied Esports Entertainment', 'Alta Mesa Resources', 'Alta Mesa Resources', 'BIQI International Holdings Corporation', 'China Lending Corporation', 'China TechFaith Wireless Communication Technology Limited', 'ChinaCache International Holdings Ltd.', 'Cray Inc', "Del Frisco's Restaurant Group", 'Diversicare Healthcare Services Inc.', 'Emmaus Life Sciences', 'Emmaus Life Sciences', 'Finisar Corporation', "Fred's", 'Gladstone Capital Corporation', 'Hunter Maritime Acquisition Corp.', 'Hunter Maritime Acquisition Corp.', 'Hunter Maritime Acquisition Corp.', 'Ivy NextShares', 'Ivy NextShares', 'Ivy NextShares', 'Peak Resorts', 'Repay Holdings Corporation', 'Shutterfly', 'USA Technologies', 'USA Technologies', 'Xynomic Pharmaceuticals Holdings', 'Xynomic Pharmaceuticals Holdings', 'Xynomic Pharmaceuticals Holdings', 'Yangtze River Port and Logistics Limited ']
# ['ADOM', 'BKCH', 'AESEW', 'AMR', 'AMRWW', 'BIQI', 'CLDC', 'CNTF', 'CCIH', 'CRAY', 'DFRG', 'DVCR', 'EMMA', 'EMMAW', 'FNSR', 'FRED', 'GLADN', 'HUNT', 'HUNTU', 'HUNTW', 'IVENC', 'IVFGC', 'IVFVC', 'SKIS', 'TBRGU', 'SFLY', 'USAT', 'USATP', 'BCACU', 'XYN', 'XYNPW', 'YRIV', 'APPL']

# %%
for i in range(len(df['CONTENT'])):
    for j in range(len(st['Symbol'])):
        if st['Symbol'][j] in df['CONTENT'][i] or issuerName[j] in df['CONTENT']:
            df['STOCK ID'][i]=st['Symbol'][j]
df['STOCK ID'].describe()
# Out:
# count     0
# unique    0
# Name: STOCK ID, dtype: int64

# %%
df.to_csv("C:/data/CS/CNBC_SCRAPE.csv")
